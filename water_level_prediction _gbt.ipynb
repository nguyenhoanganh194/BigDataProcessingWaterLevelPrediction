# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import sys
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.master("local").appName("Irish Marine Institute - Data Prep").getOrCreate()

# %%
df = spark.read.csv("dataset/IrishNationalTideGaugeNetwork.csv", header=True, inferSchema=True)
df.show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  time                 | UTC
#  altitude             | m
#  latitude             | degrees_north
#  longitude            | degrees_east
#  station_id           | null
#  datasourceid         | null
#  Water_Level_LAT      | metres
#  Water_Level_OD_Malin | metres
#  QC_Flag              | null
# -RECORD 1------------------------------------
#  time                 | 2006-10-26T13:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.679
#  Water_Level_OD_Malin | 1.82
#  QC_Flag              | 1
# -RECORD 2------------------------------------
#  time                 | 2006-10-26T14:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.939
#  Water_Level_OD_Malin | 2.08
#  QC_Flag              | 1
# -RECORD 3------------------------------------
#  time                 | 2006-10-26T14:06:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.969
#  Water_Level_OD_Malin | 2.11
#  QC_Flag              | 1
# -RECORD 4------------------------------------
#  time                 | 2006-10-26T14:12:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.859
#  Water_Level_OD_Malin | 2.0
#  QC_Flag              | 1
# -RECORD 5------------------------------------
#  time                 | 2006-10-26T14:18:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.809
#  Water_Level_OD_Malin | 1.95
#  QC_Flag              | 1
# -RECORD 6------------------------------------
#  time                 | 2006-10-26T14:24:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.789
#  Water_Level_OD_Malin | 1.93
#  QC_Flag              | 1
# -RECORD 7------------------------------------
#  time                 | 2006-10-26T14:30:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.739
#  Water_Level_OD_Malin | 1.88
#  QC_Flag              | 1
# -RECORD 8------------------------------------
#  time                 | 2006-10-26T14:36:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.669
#  Water_Level_OD_Malin | 1.81
#  QC_Flag              | 1
# -RECORD 9------------------------------------
#  time                 | 2006-10-26T14:42:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.609
#  Water_Level_OD_Malin | 1.75
#  QC_Flag              | 1
# -RECORD 10-----------------------------------
#  time                 | 2006-10-26T14:48:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.579
#  Water_Level_OD_Malin | 1.72
#  QC_Flag              | 1
# -RECORD 11-----------------------------------
#  time                 | 2006-10-26T14:54:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.499
#  Water_Level_OD_Malin | 1.64
#  QC_Flag              | 1
# -RECORD 12-----------------------------------
#  time                 | 2006-10-26T15:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.479
#  Water_Level_OD_Malin | 1.62
#  QC_Flag              | 1
# -RECORD 13-----------------------------------
#  time                 | 2006-10-26T15:06:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.359
#  Water_Level_OD_Malin | 1.5
#  QC_Flag              | 1
# -RECORD 14-----------------------------------
#  time                 | 2006-10-26T15:12:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.289
#  Water_Level_OD_Malin | 1.43
#  QC_Flag              | 1
# -RECORD 15-----------------------------------
#  time                 | 2006-10-26T15:18:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.259
#  Water_Level_OD_Malin | 1.4
#  QC_Flag              | 1
# -RECORD 16-----------------------------------
#  time                 | 2006-10-26T15:24:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.139
#  Water_Level_OD_Malin | 1.28
#  QC_Flag              | 1
# -RECORD 17-----------------------------------
#  time                 | 2006-10-26T15:30:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.049
#  Water_Level_OD_Malin | 1.19
#  QC_Flag              | 1
# -RECORD 18-----------------------------------
#  time                 | 2006-10-26T15:36:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 3.969
#  Water_Level_OD_Malin | 1.11
#  QC_Flag              | 1
# -RECORD 19-----------------------------------
#  time                 | 2006-10-26T15:42:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 3.859
#  Water_Level_OD_Malin | 1.0
#  QC_Flag              | 1
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- time: string (nullable = true)
#  |-- altitude: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- station_id: string (nullable = true)
#  |-- datasourceid: integer (nullable = true)
#  |-- Water_Level_LAT: string (nullable = true)
#  |-- Water_Level_OD_Malin: string (nullable = true)
#  |-- QC_Flag: integer (nullable = true)

# %%
from pyspark.sql.functions import from_utc_timestamp
from pyspark.sql.functions import col
from pyspark.sql.functions import year, to_date
from pyspark.sql.functions import dayofmonth, month, year,hour, minute

# Convert the string column to a datetime column
df = df.withColumn("Water_Level_LAT", col("Water_Level_LAT").cast("float"))
df = df.withColumn("Water_Level_OD_Malin", col("Water_Level_OD_Malin").cast("float"))
df = df.withColumn("latitude", col("latitude").cast("float"))
df = df.withColumn("longitude", col("longitude").cast("float"))

df = df.withColumn("minute", minute(to_date(df.time)))
df = df.withColumn("hour", hour(to_date(df.time)))
df = df.withColumn("day", dayofmonth(to_date(df.time)))
df = df.withColumn("month", month(to_date(df.time)))
df = df.withColumn("year", year(to_date(df.time)))


df = df.withColumn("day", dayofmonth(to_date(df.time)))
df = df.withColumn("month", month(to_date(df.time)))
df = df.withColumn("year", year(to_date(df.time)))

df = df.filter((df.latitude == '53.585') & (df.longitude == '-6.1081'))
df = df.na.drop()
df.show()
df.printSchema()
# Out:
# +--------------------+--------+--------+---------+----------------+------------+---------------+--------------------+-------+------+----+---+-----+----+
# |                time|altitude|latitude|longitude|      station_id|datasourceid|Water_Level_LAT|Water_Level_OD_Malin|QC_Flag|minute|hour|day|month|year|
# +--------------------+--------+--------+---------+----------------+------------+---------------+--------------------+-------+------+----+---+-----+----+
# |2006-10-26T13:00:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.679|                1.82|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:00:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.939|                2.08|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:06:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.969|                2.11|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:12:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.859|                 2.0|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:18:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.809|                1.95|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:24:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.789|                1.93|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:30:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.739|                1.88|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:36:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.669|                1.81|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:42:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.609|                1.75|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:48:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.579|                1.72|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:54:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.499|                1.64|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:00:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.479|                1.62|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:06:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.359|                 1.5|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:12:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.289|                1.43|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:18:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.259|                 1.4|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:24:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.139|                1.28|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:30:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.049|                1.19|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:36:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          3.969|                1.11|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:42:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          3.859|                 1.0|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:48:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          3.809|                0.95|      1|     0|   0| 26|   10|2006|
# +--------------------+--------+--------+---------+----------------+------------+---------------+--------------------+-------+------+----+---+-----+----+
# only showing top 20 rows
#
# root
#  |-- time: string (nullable = true)
#  |-- altitude: string (nullable = true)
#  |-- latitude: float (nullable = true)
#  |-- longitude: float (nullable = true)
#  |-- station_id: string (nullable = true)
#  |-- datasourceid: integer (nullable = true)
#  |-- Water_Level_LAT: float (nullable = true)
#  |-- Water_Level_OD_Malin: float (nullable = true)
#  |-- QC_Flag: integer (nullable = true)
#  |-- minute: integer (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- year: integer (nullable = true)

# %%
df.dtypes
# Out:
# [('time', 'string'),
#  ('altitude', 'string'),
#  ('latitude', 'float'),
#  ('longitude', 'float'),
#  ('station_id', 'string'),
#  ('datasourceid', 'int'),
#  ('Water_Level_LAT', 'float'),
#  ('Water_Level_OD_Malin', 'float'),
#  ('QC_Flag', 'int'),
#  ('minute', 'int'),
#  ('hour', 'int'),
#  ('day', 'int'),
#  ('month', 'int'),
#  ('year', 'int')]

# %%
from pyspark.ml.feature import StringIndexer
indexer = StringIndexer(inputCol="time" ,outputCol="indexedTime")
indexed = indexer.fit(df).transform(df)
indexed.show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  time                 | 2006-10-26T13:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.679
#  Water_Level_OD_Malin | 1.82
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 0.0
# -RECORD 1------------------------------------
#  time                 | 2006-10-26T14:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.939
#  Water_Level_OD_Malin | 2.08
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 1.0
# -RECORD 2------------------------------------
#  time                 | 2006-10-26T14:06:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.969
#  Water_Level_OD_Malin | 2.11
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 2.0
# -RECORD 3------------------------------------
#  time                 | 2006-10-26T14:12:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.859
#  Water_Level_OD_Malin | 2.0
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 3.0
# -RECORD 4------------------------------------
#  time                 | 2006-10-26T14:18:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.809
#  Water_Level_OD_Malin | 1.95
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 4.0
# -RECORD 5------------------------------------
#  time                 | 2006-10-26T14:24:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.789
#  Water_Level_OD_Malin | 1.93
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 5.0
# -RECORD 6------------------------------------
#  time                 | 2006-10-26T14:30:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.739
#  Water_Level_OD_Malin | 1.88
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 6.0
# -RECORD 7------------------------------------
#  time                 | 2006-10-26T14:36:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.669
#  Water_Level_OD_Malin | 1.81
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 7.0
# -RECORD 8------------------------------------
#  time                 | 2006-10-26T14:42:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.609
#  Water_Level_OD_Malin | 1.75
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 8.0
# -RECORD 9------------------------------------
#  time                 | 2006-10-26T14:48:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.579
#  Water_Level_OD_Malin | 1.72
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 9.0
# -RECORD 10-----------------------------------
#  time                 | 2006-10-26T14:54:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.499
#  Water_Level_OD_Malin | 1.64
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 10.0
# -RECORD 11-----------------------------------
#  time                 | 2006-10-26T15:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.479
#  Water_Level_OD_Malin | 1.62
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 11.0
# -RECORD 12-----------------------------------
#  time                 | 2006-10-26T15:06:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.359
#  Water_Level_OD_Malin | 1.5
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 12.0
# -RECORD 13-----------------------------------
#  time                 | 2006-10-26T15:12:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.289
#  Water_Level_OD_Malin | 1.43
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 13.0
# -RECORD 14-----------------------------------
#  time                 | 2006-10-26T15:18:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.259
#  Water_Level_OD_Malin | 1.4
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 14.0
# -RECORD 15-----------------------------------
#  time                 | 2006-10-26T15:24:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.139
#  Water_Level_OD_Malin | 1.28
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 15.0
# -RECORD 16-----------------------------------
#  time                 | 2006-10-26T15:30:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.049
#  Water_Level_OD_Malin | 1.19
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 16.0
# -RECORD 17-----------------------------------
#  time                 | 2006-10-26T15:36:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 3.969
#  Water_Level_OD_Malin | 1.11
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 17.0
# -RECORD 18-----------------------------------
#  time                 | 2006-10-26T15:42:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 3.859
#  Water_Level_OD_Malin | 1.0
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 18.0
# -RECORD 19-----------------------------------
#  time                 | 2006-10-26T15:48:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 3.809
#  Water_Level_OD_Malin | 0.95
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 19.0
# only showing top 20 rows

# %%
fd_1 = indexed.selectExpr("cast(time as string)dateTime",
                          "cast(minute as int)minute",
                          "cast(hour as int)hour",
                          "cast(day as int)day",
                          "cast(month as int)month",
                          "cast(year as int)year",
                          "cast(Water_Level_LAT as float)label",
                          "cast(Water_Level_OD_Malin as float) Water_Level_OD_Malin")

tran_fd_1 = fd_1.filter((fd_1.year < 2020))
test_fd_1 = fd_1.filter((fd_1.year > 2019))

# %%
from pyspark.ml.feature import VectorAssembler
vectorAssembler = VectorAssembler(inputCols = ['minute','hour','day','month','year'],
                                  handleInvalid="skip",
                                  outputCol ='features')

vhouse_df = vectorAssembler.transform(fd_1)
trSet = vhouse_df.select("features", "label")

# %%
vhouse_df_tran = vectorAssembler.transform(tran_fd_1)
trainingData = vhouse_df_tran.select("features", "label")
trainingData.show()

vhouse_df_test = vectorAssembler.transform(test_fd_1)
testData = vhouse_df_test.select("features", "label")
testData.show()
# Out:
# +--------------------+-----+
# |            features|label|
# +--------------------+-----+
# |[0.0,0.0,26.0,10....|4.679|
# |[0.0,0.0,26.0,10....|4.939|
# |[0.0,0.0,26.0,10....|4.969|
# |[0.0,0.0,26.0,10....|4.859|
# |[0.0,0.0,26.0,10....|4.809|
# |[0.0,0.0,26.0,10....|4.789|
# |[0.0,0.0,26.0,10....|4.739|
# |[0.0,0.0,26.0,10....|4.669|
# |[0.0,0.0,26.0,10....|4.609|
# |[0.0,0.0,26.0,10....|4.579|
# |[0.0,0.0,26.0,10....|4.499|
# |[0.0,0.0,26.0,10....|4.479|
# |[0.0,0.0,26.0,10....|4.359|
# |[0.0,0.0,26.0,10....|4.289|
# |[0.0,0.0,26.0,10....|4.259|
# |[0.0,0.0,26.0,10....|4.139|
# |[0.0,0.0,26.0,10....|4.049|
# |[0.0,0.0,26.0,10....|3.969|
# |[0.0,0.0,26.0,10....|3.859|
# |[0.0,0.0,26.0,10....|3.809|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-------+
# |            features|  label|
# +--------------------+-------+
# |[0.0,0.0,3.0,11.0...|-29.904|
# |[0.0,0.0,3.0,11.0...|-29.904|
# |[0.0,0.0,3.0,11.0...|-29.904|
# |[0.0,0.0,3.0,11.0...|-29.899|
# |[0.0,0.0,3.0,11.0...|-29.904|
# |[0.0,0.0,3.0,11.0...|  3.097|
# |[0.0,0.0,3.0,11.0...|  3.022|
# |[0.0,0.0,3.0,11.0...|  2.965|
# |[0.0,0.0,3.0,11.0...|  2.897|
# |[0.0,0.0,3.0,11.0...|  2.801|
# |[0.0,0.0,3.0,11.0...|   2.72|
# |[0.0,0.0,3.0,11.0...|  2.637|
# |[0.0,0.0,3.0,11.0...|  2.561|
# |[0.0,0.0,3.0,11.0...|  2.477|
# |[0.0,0.0,3.0,11.0...|  2.399|
# |[0.0,0.0,3.0,11.0...|  2.326|
# |[0.0,0.0,3.0,11.0...|  2.241|
# |[0.0,0.0,3.0,11.0...|  2.158|
# |[0.0,0.0,3.0,11.0...|  2.076|
# |[0.0,0.0,3.0,11.0...|  2.005|
# +--------------------+-------+
# only showing top 20 rows

# %%
from pyspark.ml.regression import GBTRegressor
from pyspark.ml.feature import VectorIndexer
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline
featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures",
                               handleInvalid="skip").fit(trSet)
gbt = GBTRegressor(featuresCol="indexedFeatures", maxIter=30, maxDepth = 11)
pipeline = Pipeline(stages=[featureIndexer, gbt])
model0 = pipeline.fit(trainingData)
tdata2 = model0.transform(testData)
evaluator = RegressionEvaluator(labelCol="label", predictionCol="prediction", metricName="r2")
rmse = evaluator.evaluate(tdata2)
print("R Squared on test data = %g" % rmse)
gbtModel = model0.stages[1]
print(gbtModel) 
model0.stages[1].featureImportances
model0.stages[-1].trees
# Out:
# R Squared on test data = -72052.4
# GBTRegressionModel: uid=GBTRegressor_61d0daef4312, numTrees=30, numFeatures=5
# SparseVector(5, {2: 0.083, 3: 0.0635, 4: 0.8535})
# [DecisionTreeRegressionModel: uid=dtr_33855f5bb5ae, depth=11, numNodes=1195, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_7f14c92e9efd, depth=11, numNodes=1085, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_91c795fbf4cc, depth=11, numNodes=1091, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_23fa41061cc1, depth=11, numNodes=1419, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_d3d1a21fde85, depth=11, numNodes=1397, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_ed1868a215f6, depth=11, numNodes=1447, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_31a1b4cf65aa, depth=11, numNodes=1691, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_48ba5cffe2f7, depth=11, numNodes=1703, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_a618eeab722b, depth=11, numNodes=1689, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_287a84f88d63, depth=11, numNodes=1877, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_20861a24039e, depth=11, numNodes=1835, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_74a4f37c62b3, depth=11, numNodes=1873, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_3d6437ffd7b9, depth=11, numNodes=889, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_d447d88c97ad, depth=11, numNodes=1455, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_ba59c7b9f9ef, depth=11, numNodes=1789, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_f39784db34a0, depth=11, numNodes=1711, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_95f03b7df14f, depth=11, numNodes=1385, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_c9c8a8913b82, depth=11, numNodes=1467, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_c43e5cfda844, depth=11, numNodes=663, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_020617122c60, depth=11, numNodes=933, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_e97820c300a3, depth=11, numNodes=1167, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_e7ab11e14976, depth=11, numNodes=1637, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_58ecb34152fa, depth=11, numNodes=1749, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_61d0d2c75168, depth=11, numNodes=1729, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_6c58ad8dd483, depth=11, numNodes=1335, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_fa50c3330942, depth=11, numNodes=1275, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_ecf743f3d521, depth=11, numNodes=1399, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_edb0baef0b3d, depth=11, numNodes=1351, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_09c158885a9a, depth=11, numNodes=1399, numFeatures=5,
#  DecisionTreeRegressionModel: uid=dtr_2b729376af58, depth=11, numNodes=1533, numFeatures=5]

# %%
from pyspark.sql import SparkSession, functions as F
from pyspark.sql.functions import lit
df2 = spark.sql("SELECT sequence(to_date('2023-01-01 14:00:00'), to_date('2023-12-31 14:00:00'), interval 1 day) as time").withColumn('time', F.explode('time'))

df2 = df2.withColumn("day", dayofmonth(df2.time))
df2 = df2.withColumn("month", month(df2.time))
df2 = df2.withColumn("year", year(df2.time))
df2 = df2.withColumn("hour", lit(12))
df2 = df2.withColumn("minute", lit(0))
df2 = df2.withColumn("timeString", col("time").cast("string"))
df2.show()
# Out:
# +----------+---+-----+----+----+------+----------+
# |      time|day|month|year|hour|minute|timeString|
# +----------+---+-----+----+----+------+----------+
# |2023-01-01|  1|    1|2023|  12|     0|2023-01-01|
# |2023-01-02|  2|    1|2023|  12|     0|2023-01-02|
# |2023-01-03|  3|    1|2023|  12|     0|2023-01-03|
# |2023-01-04|  4|    1|2023|  12|     0|2023-01-04|
# |2023-01-05|  5|    1|2023|  12|     0|2023-01-05|
# |2023-01-06|  6|    1|2023|  12|     0|2023-01-06|
# |2023-01-07|  7|    1|2023|  12|     0|2023-01-07|
# |2023-01-08|  8|    1|2023|  12|     0|2023-01-08|
# |2023-01-09|  9|    1|2023|  12|     0|2023-01-09|
# |2023-01-10| 10|    1|2023|  12|     0|2023-01-10|
# |2023-01-11| 11|    1|2023|  12|     0|2023-01-11|
# |2023-01-12| 12|    1|2023|  12|     0|2023-01-12|
# |2023-01-13| 13|    1|2023|  12|     0|2023-01-13|
# |2023-01-14| 14|    1|2023|  12|     0|2023-01-14|
# |2023-01-15| 15|    1|2023|  12|     0|2023-01-15|
# |2023-01-16| 16|    1|2023|  12|     0|2023-01-16|
# |2023-01-17| 17|    1|2023|  12|     0|2023-01-17|
# |2023-01-18| 18|    1|2023|  12|     0|2023-01-18|
# |2023-01-19| 19|    1|2023|  12|     0|2023-01-19|
# |2023-01-20| 20|    1|2023|  12|     0|2023-01-20|
# +----------+---+-----+----+----+------+----------+
# only showing top 20 rows

# %%
indexer = StringIndexer(inputCol="timeString" ,outputCol="indexedTime")
indexed_predict = indexer.fit(df2).transform(df2)
indexed_predict.show(vertical=True)
# Out:
# -RECORD 0-----------------
#  time        | 2023-01-01
#  day         | 1
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-01
#  indexedTime | 0.0
# -RECORD 1-----------------
#  time        | 2023-01-02
#  day         | 2
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-02
#  indexedTime | 1.0
# -RECORD 2-----------------
#  time        | 2023-01-03
#  day         | 3
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-03
#  indexedTime | 2.0
# -RECORD 3-----------------
#  time        | 2023-01-04
#  day         | 4
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-04
#  indexedTime | 3.0
# -RECORD 4-----------------
#  time        | 2023-01-05
#  day         | 5
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-05
#  indexedTime | 4.0
# -RECORD 5-----------------
#  time        | 2023-01-06
#  day         | 6
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-06
#  indexedTime | 5.0
# -RECORD 6-----------------
#  time        | 2023-01-07
#  day         | 7
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-07
#  indexedTime | 6.0
# -RECORD 7-----------------
#  time        | 2023-01-08
#  day         | 8
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-08
#  indexedTime | 7.0
# -RECORD 8-----------------
#  time        | 2023-01-09
#  day         | 9
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-09
#  indexedTime | 8.0
# -RECORD 9-----------------
#  time        | 2023-01-10
#  day         | 10
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-10
#  indexedTime | 9.0
# -RECORD 10----------------
#  time        | 2023-01-11
#  day         | 11
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-11
#  indexedTime | 10.0
# -RECORD 11----------------
#  time        | 2023-01-12
#  day         | 12
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-12
#  indexedTime | 11.0
# -RECORD 12----------------
#  time        | 2023-01-13
#  day         | 13
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-13
#  indexedTime | 12.0
# -RECORD 13----------------
#  time        | 2023-01-14
#  day         | 14
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-14
#  indexedTime | 13.0
# -RECORD 14----------------
#  time        | 2023-01-15
#  day         | 15
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-15
#  indexedTime | 14.0
# -RECORD 15----------------
#  time        | 2023-01-16
#  day         | 16
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-16
#  indexedTime | 15.0
# -RECORD 16----------------
#  time        | 2023-01-17
#  day         | 17
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-17
#  indexedTime | 16.0
# -RECORD 17----------------
#  time        | 2023-01-18
#  day         | 18
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-18
#  indexedTime | 17.0
# -RECORD 18----------------
#  time        | 2023-01-19
#  day         | 19
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-19
#  indexedTime | 18.0
# -RECORD 19----------------
#  time        | 2023-01-20
#  day         | 20
#  month       | 1
#  year        | 2023
#  hour        | 12
#  minute      | 0
#  timeString  | 2023-01-20
#  indexedTime | 19.0
# only showing top 20 rows

# %%
fd_2 = indexed_predict.selectExpr("cast(time as string)dateTime",
                          "cast(minute as int)minute",
                          "cast(hour as int)hour",
                          "cast(day as int)day",
                          "cast(month as int)month",
                          "cast(year as int)year")

vhouse_df2 = vectorAssembler.transform(fd_2)
predictSet = vhouse_df2.select("features","dateTime")
predictSet.show(truncate=False)
# Out:
# +--------------------------+----------+
# |features                  |dateTime  |
# +--------------------------+----------+
# |[0.0,12.0,1.0,1.0,2023.0] |2023-01-01|
# |[0.0,12.0,2.0,1.0,2023.0] |2023-01-02|
# |[0.0,12.0,3.0,1.0,2023.0] |2023-01-03|
# |[0.0,12.0,4.0,1.0,2023.0] |2023-01-04|
# |[0.0,12.0,5.0,1.0,2023.0] |2023-01-05|
# |[0.0,12.0,6.0,1.0,2023.0] |2023-01-06|
# |[0.0,12.0,7.0,1.0,2023.0] |2023-01-07|
# |[0.0,12.0,8.0,1.0,2023.0] |2023-01-08|
# |[0.0,12.0,9.0,1.0,2023.0] |2023-01-09|
# |[0.0,12.0,10.0,1.0,2023.0]|2023-01-10|
# |[0.0,12.0,11.0,1.0,2023.0]|2023-01-11|
# |[0.0,12.0,12.0,1.0,2023.0]|2023-01-12|
# |[0.0,12.0,13.0,1.0,2023.0]|2023-01-13|
# |[0.0,12.0,14.0,1.0,2023.0]|2023-01-14|
# |[0.0,12.0,15.0,1.0,2023.0]|2023-01-15|
# |[0.0,12.0,16.0,1.0,2023.0]|2023-01-16|
# |[0.0,12.0,17.0,1.0,2023.0]|2023-01-17|
# |[0.0,12.0,18.0,1.0,2023.0]|2023-01-18|
# |[0.0,12.0,19.0,1.0,2023.0]|2023-01-19|
# |[0.0,12.0,20.0,1.0,2023.0]|2023-01-20|
# +--------------------------+----------+
# only showing top 20 rows

# %%
result = model0.transform(predictSet)
result.show(truncate=False)
tdata2.show()
# Out:
# +--------+--------+---------------+----------+
# |features|dateTime|indexedFeatures|prediction|
# +--------+--------+---------------+----------+
# +--------+--------+---------------+----------+
#
# +--------------------+-------+--------------------+----------------+
# |            features|  label|     indexedFeatures|      prediction|
# +--------------------+-------+--------------------+----------------+
# |[0.0,0.0,3.0,11.0...|-29.904|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|-29.904|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|-29.904|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|-29.899|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|-29.904|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  3.097|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  3.022|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.965|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.897|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.801|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|   2.72|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.637|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.561|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.477|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.399|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.326|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.241|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.158|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.076|[0.0,0.0,3.0,10.0...|330.651157216327|
# |[0.0,0.0,3.0,11.0...|  2.005|[0.0,0.0,3.0,10.0...|330.651157216327|
# +--------------------+-------+--------------------+----------------+
# only showing top 20 rows

# %%
import matplotlib.pyplot as plt

dates = [row[0] for row in result.select("dateTime").collect()]
values = [row[0] for row in result.select("prediction").collect()]

# Plot the graph
plt.plot(dates, values)
plt.xlabel("Date-Time")
plt.ylabel("Value")
plt.title("Graph of Value over Time")
plt.show()

# %%
draw = df.filter((df.year == '2022'))
new_df = draw.select("name", "country")


draw.show()
draw.count()

# %%
dates = [row[0] for row in draw.select("time").collect()]
values = [row[0] for row in draw.select("Water_Level_LAT").collect()]

# Plot the graph
plt.plot(dates, values)
plt.xlabel("Date-Time")
plt.ylabel("Value")
plt.title("Graph of Value over Time")
plt.show()
