# %%
import os
import requests

from datetime import datetime
from tqdm import tqdm

from pyspark import SparkFiles
from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local").appName("Irish Marine Institute - Data Prep").getOrCreate()

# %%
dataset_dir = 'dataset'
dataset_base_url = "https://erddap.marine.ie/erddap/tabledap/"
dataset_ids = ["allDatasets", "IrishNationalTideGaugeNetwork", "IMI-TidePrediction", "IWaveBNetwork30Min", "IWaveBNetwork_spectral"]
dataset_format = "csv"

t_0 = datetime(2003, 1, 1)
t_1 = datetime(2024, 1, 1)

# %%
def fetch_data(dataset_id, file_format, keys = None, t_range = None, orderby = None, distinct = False):
    os.makedirs(dataset_dir, exist_ok=True)
    file_name = f"{dataset_id}{'_meta' if distinct else ''}.{file_format}"
    file_path = os.path.join(dataset_dir, file_name)
    
    keys_str = ','.join(keys) if keys else ''
    orderby_str = f"&orderBy(\"{','.join(orderby)}\")" if orderby else ''
    t_range_str = (f"&time>={t_range[0].isoformat()}" if t_range else '') + (f"&time<={t_range[1].isoformat()}" if t_range and len(t_range) == 2 else '')
    
    if os.path.isfile(file_path):
        print(f"File {file_path} already exists")
    else:
        print(f"Downloading {file_path} ...")
        url = f"{dataset_base_url}{dataset_id}.{file_format}?{keys_str}{'&distinct()' if distinct else ''}{t_range_str}{orderby_str}"
        res = requests.get(url, allow_redirects=True)
        with open(file_path, 'wb') as f:
            f.write(res.content)
    
    return file_path

# %%
# fetch data
data_paths = []
for dataset_id in tqdm(dataset_ids):
    if dataset_id == "allDatasets":
        data_paths.append(fetch_data("allDatasets", dataset_format, None, None, ["institution", "datasetID", "title"], True))
    else:
        s_id = "stationID" if dataset_id == 'IMI-TidePrediction' else "station_id"
        data_paths.append(fetch_data(dataset_id, dataset_format, ["longitude", "latitude", s_id], None, None, True))
        data_paths.append(fetch_data(dataset_id, dataset_format, None, [t_0, t_1], None))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading dataset\allDatasets_meta.csv ...
#  20%|██        | 1/5 [00:00<00:01,  2.88it/s]
# Downloading dataset\IrishNationalTideGaugeNetwork_meta.csv ...
# Downloading dataset\IrishNationalTideGaugeNetwork.csv ...
#  40%|████      | 2/5 [02:40<04:43, 94.43s/it]
# Downloading dataset\IMI-TidePrediction_meta.csv ...
# Downloading dataset\IMI-TidePrediction.csv ...
#  60%|██████    | 3/5 [02:55<01:55, 57.89s/it]
# Downloading dataset\IWaveBNetwork30Min_meta.csv ...
# Downloading dataset\IWaveBNetwork30Min.csv ...
#  80%|████████  | 4/5 [04:15<01:06, 66.66s/it]
# Downloading dataset\IWaveBNetwork_spectral_meta.csv ...
# Downloading dataset\IWaveBNetwork_spectral.csv ...
# 100%|██████████| 5/5 [04:22<00:00, 52.49s/it]

# %%
for data_path in data_paths:
    spark.sparkContext.addFile(data_path)

# %%
df = spark.read.csv(SparkFiles.get(os.path.join(os.getcwd(), 'dataset/allDatasets_meta.csv')), header=True, inferSchema=True)

# %%
df.printSchema()
# Out:
# root
#  |-- datasetID: string (nullable = true)
#  |-- accessible: string (nullable = true)
#  |-- institution: string (nullable = true)
#  |-- dataStructure: string (nullable = true)
#  |-- cdm_data_type: string (nullable = true)
#  |-- class: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- minLongitude: string (nullable = true)
#  |-- maxLongitude: string (nullable = true)
#  |-- longitudeSpacing: string (nullable = true)
#  |-- minLatitude: string (nullable = true)
#  |-- maxLatitude: string (nullable = true)
#  |-- latitudeSpacing: string (nullable = true)
#  |-- minAltitude: string (nullable = true)
#  |-- maxAltitude: string (nullable = true)
#  |-- minTime: string (nullable = true)
#  |-- maxTime: string (nullable = true)
#  |-- timeSpacing: string (nullable = true)
#  |-- griddap: string (nullable = true)
#  |-- subset: string (nullable = true)
#  |-- tabledap: string (nullable = true)
#  |-- MakeAGraph: string (nullable = true)
#  |-- sos: string (nullable = true)
#  |-- wcs: string (nullable = true)
#  |-- wms: string (nullable = true)
#  |-- files: string (nullable = true)
#  |-- fgdc: string (nullable = true)
#  |-- iso19115: string (nullable = true)
#  |-- metadata: string (nullable = true)
#  |-- sourceUrl: string (nullable = true)
#  |-- infoUrl: string (nullable = true)
#  |-- rss: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- testOutOfDate: string (nullable = true)
#  |-- outOfDate: double (nullable = true)
#  |-- summary: string (nullable = true)

# %%
df.show(vertical=True)
# Out:
# -RECORD 0--------------------------------
#  datasetID        | null
#  accessible       | null
#  institution      | null
#  dataStructure    | null
#  cdm_data_type    | null
#  class            | null
#  title            | null
#  minLongitude     | degrees_east
#  maxLongitude     | degrees_east
#  longitudeSpacing | degrees_east
#  minLatitude      | degrees_north
#  maxLatitude      | degrees_north
#  latitudeSpacing  | degrees_north
#  minAltitude      | m
#  maxAltitude      | m
#  minTime          | UTC
#  maxTime          | UTC
#  timeSpacing      | seconds
#  griddap          | null
#  subset           | null
#  tabledap         | null
#  MakeAGraph       | null
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | null
#  fgdc             | null
#  iso19115         | null
#  metadata         | null
#  sourceUrl        | null
#  infoUrl          | null
#  rss              | null
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | null
#  summary          | null
# -RECORD 1--------------------------------
#  datasetID        | AORA_asc
#  accessible       | public
#  institution      | AORA
#  dataStructure    | grid
#  cdm_data_type    | Grid
#  class            | EDDGridFromNcFiles
#  title            | AORA Bathymetry
#  minLongitude     | -53.046577782043606
#  maxLongitude     | -10.430871044850768
#  longitudeSpacing | 5.7443631279325E-4
#  minLatitude      | 45.932321493156394
#  maxLatitude      | 54.48108270014554
#  latitudeSpacing  | 5.744363127932501E-4
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | null
#  maxTime          | null
#  timeSpacing      | NaN
#  griddap          | https://erddap.ma...
#  subset           | null
#  tabledap         | null
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | https://erddap.ma...
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | (local files)
#  infoUrl          | http://data.marin...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | Atlantic Ocean Re...
# -RECORD 2--------------------------------
#  datasetID        | argoFloats
#  accessible       | public
#  institution      | Argo
#  dataStructure    | table
#  cdm_data_type    | TrajectoryProfile
#  class            | EDDTableFromMulti...
#  title            | Argo Float Vertic...
#  minLongitude     | -60.103
#  maxLongitude     | 32.11416166666667
#  longitudeSpacing | NaN
#  minLatitude      | 4.865351666666667
#  maxLatitude      | 82.62766833333333
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | 2003-10-22T03:10:17Z
#  maxTime          | 2023-05-07T13:07:19Z
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | https://erddap.ma...
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | (local files)
#  infoUrl          | http://www.argo.net/
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | "Argo float verti...
# -RECORD 3--------------------------------
#  datasetID        | mestech
#  accessible       | public
#  institution      | Dublin City Unive...
#  dataStructure    | table
#  cdm_data_type    | Point
#  class            | EDDTableFromDatabase
#  title            | MESTECH Multipara...
#  minLongitude     | NaN
#  maxLongitude     | NaN
#  longitudeSpacing | NaN
#  minLatitude      | NaN
#  maxLatitude      | NaN
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | null
#  maxTime          | null
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | (source database)
#  infoUrl          | http://www.mestec...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | Environmental Sen...
# -RECORD 4--------------------------------
#  datasetID        | GFS-WeatherTimeSe...
#  accessible       | public
#  institution      | ECMWF
#  dataStructure    | table
#  cdm_data_type    | TimeSeries
#  class            | EDDTableFromNcFiles
#  title            | ECMWF weather for...
#  minLongitude     | -10.0
#  maxLongitude     | -6.0
#  longitudeSpacing | NaN
#  minLatitude      | 51.4
#  maxLatitude      | 55.3
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | 2023-05-07T01:00:00Z
#  maxTime          | 2023-05-13T00:00:00Z
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | https://erddap.ma...
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | http://www.marine...
#  infoUrl          | https://www.ecmwf...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | ECMWF weather for...
# -RECORD 5--------------------------------
#  datasetID        | BANTRY_PARTICLES
#  accessible       | public
#  institution      | Irish Marine Inst...
#  dataStructure    | grid
#  cdm_data_type    | Grid
#  class            | EDDGridFromDap
#  title            | Bantry Bay model ...
#  minLongitude     | -10.848548076923
#  maxLongitude     | -9.3414519231008
#  longitudeSpacing | 0.0029038461538
#  minLatitude      | 51.140912310003
#  maxLatitude      | 51.899102770785255
#  latitudeSpacing  | 0.001809523772750...
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | 2023-04-07T00:00:00Z
#  maxTime          | 2023-05-08T00:00:00Z
#  timeSpacing      | 92358.62068965517
#  griddap          | https://erddap.ma...
#  subset           | null
#  tabledap         | null
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | https://erddap.ma...
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | http://milas.mari...
#  infoUrl          | http://milas.mari...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | Aggregate model p...
# -RECORD 6--------------------------------
#  datasetID        | IMI_CONN_2D
#  accessible       | public
#  institution      | Irish Marine Inst...
#  dataStructure    | grid
#  cdm_data_type    | Grid
#  class            | EDDGridFromDap
#  title            | Irish Marine Inst...
#  minLongitude     | -10.79851171874996
#  maxLongitude     | -8.89648828124996
#  longitudeSpacing | 0.002976562500000001
#  minLatitude      | 52.95089447171561
#  maxLatitude      | 53.72912172247213
#  latitudeSpacing  | 0.001772727222680...
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | 2023-05-04T00:00:00Z
#  maxTime          | 2023-05-11T00:00:00Z
#  timeSpacing      | 3600.0
#  griddap          | https://erddap.ma...
#  subset           | null
#  tabledap         | null
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | https://erddap.ma...
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | http://milas.mari...
#  infoUrl          | http://milas.mari...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | CONN2D
# -RECORD 7--------------------------------
#  datasetID        | IMI_CONN_3D
#  accessible       | public
#  institution      | Irish Marine Inst...
#  dataStructure    | grid
#  cdm_data_type    | Grid
#  class            | EDDGridFromDap
#  title            | Irish Marine Inst...
#  minLongitude     | -10.79851171874996
#  maxLongitude     | -8.89648828124996
#  longitudeSpacing | 0.002976562500000001
#  minLatitude      | 52.95089447171561
#  maxLatitude      | 53.72912172247213
#  latitudeSpacing  | 0.001772727222680...
#  minAltitude      | 1.0
#  maxAltitude      | 20.0
#  minTime          | 2023-05-04T00:00:00Z
#  maxTime          | 2023-05-11T00:00:00Z
#  timeSpacing      | 3600.0
#  griddap          | https://erddap.ma...
#  subset           | null
#  tabledap         | null
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | https://erddap.ma...
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | http://milas.mari...
#  infoUrl          | http://milas.mari...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | CONN3D
# -RECORD 8--------------------------------
#  datasetID        | IMI_EATL_WAVE
#  accessible       | public
#  institution      | Irish Marine Inst...
#  dataStructure    | grid
#  cdm_data_type    | Grid
#  class            | EDDGridFromDap
#  title            | East Atlantic SWA...
#  minLongitude     | -19.9875
#  maxLongitude     | -0.01249999999999929
#  longitudeSpacing | 0.025
#  minLatitude      | 36.5125
#  maxLatitude      | 59.987500000000004
#  latitudeSpacing  | 0.025
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | 2023-04-08T00:00:00Z
#  maxTime          | 2023-05-12T21:00:00Z
#  timeSpacing      | 10800.0
#  griddap          | https://erddap.ma...
#  subset           | null
#  tabledap         | null
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | https://erddap.ma...
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | http://milas.mari...
#  infoUrl          | http://milas.mari...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | Wave model data
# -RECORD 9--------------------------------
#  datasetID        | IMI_Model_Stats
#  accessible       | public
#  institution      | Irish Marine Inst...
#  dataStructure    | grid
#  cdm_data_type    | Grid
#  class            | EDDGridFromDap
#  title            | Model Monthly Means
#  minLongitude     | -17.9875
#  maxLongitude     | -2.0125
#  longitudeSpacing | 0.025
#  minLatitude      | 48.0125
#  maxLatitude      | 58.9875
#  latitudeSpacing  | 0.024999999999999988
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | 2012-01-15T00:00:00Z
#  maxTime          | 2023-04-15T00:00:00Z
#  timeSpacing      | 2629120.0
#  griddap          | https://erddap.ma...
#  subset           | null
#  tabledap         | null
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | https://erddap.ma...
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | http://milas.mari...
#  infoUrl          | http://milas.mari...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | Irish Marine Inst...
# -RECORD 10-------------------------------
#  datasetID        | IMI_NEATL
#  accessible       | public
#  institution      | Irish Marine Inst...
#  dataStructure    | grid
#  cdm_data_type    | Grid
#  class            | EDDGridFromDap
#  title            | Irish Marine Inst...
#  minLongitude     | -17.99375
#  maxLongitude     | -1.00625
#  longitudeSpacing | 0.012499999999999997
#  minLatitude      | 48.00625
#  maxLatitude      | 57.99375
#  latitudeSpacing  | 0.012499999999999997
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | 2023-04-30T00:00:00Z
#  maxTime          | 2023-05-10T00:00:00Z
#  timeSpacing      | 3600.0
#  griddap          | https://erddap.ma...
#  subset           | null
#  tabledap         | null
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | https://erddap.ma...
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | http://milas.mari...
#  infoUrl          | http://milas.mari...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | NEATL
# -RECORD 11-------------------------------
#  datasetID        | ICTempNetwork
#  accessible       | public
#  institution      | Marine Institute
#  dataStructure    | table
#  cdm_data_type    | TimeSeries
#  class            | EDDTableFromDatabase
#  title            | Coastal Temperatu...
#  minLongitude     | -10.21234
#  maxLongitude     | -7.55028
#  longitudeSpacing | NaN
#  minLatitude      | 51.64444
#  maxLatitude      | 55.20173
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | null
#  maxTime          | null
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | (source database)
#  infoUrl          | http://www.isde.i...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | Irish Coastal Tem...
# -RECORD 12-------------------------------
#  datasetID        | ICTempNetworkFres...
#  accessible       | public
#  institution      | Marine Institute
#  dataStructure    | table
#  cdm_data_type    | TimeSeries
#  class            | EDDTableFromDatabase
#  title            | Coastal Temperatu...
#  minLongitude     | -9.055611
#  maxLongitude     | -9.055611
#  longitudeSpacing | NaN
#  minLatitude      | 53.27761
#  maxLatitude      | 53.27761
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | null
#  maxTime          | null
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | (source database)
#  infoUrl          | http://www.isde.i...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | Irish Coastal Tem...
# -RECORD 13-------------------------------
#  datasetID        | IMI-TidePrediction
#  accessible       | public
#  institution      | Marine Institute
#  dataStructure    | table
#  cdm_data_type    | TimeSeries
#  class            | EDDTableFromNcFiles
#  title            | Marine Institute ...
#  minLongitude     | -10.27732
#  maxLongitude     | -6.0127
#  longitudeSpacing | NaN
#  minLatitude      | 51.559
#  maxLatitude      | 55.37168
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | 2023-01-01T00:00:00Z
#  maxTime          | 2026-01-01T00:20:00Z
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | https://erddap.ma...
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | http://www.marine...
#  infoUrl          | http://data.marin...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | Tidal predictions...
# -RECORD 14-------------------------------
#  datasetID        | IMI-TidePredictio...
#  accessible       | public
#  institution      | Marine Institute
#  dataStructure    | table
#  cdm_data_type    | TimeSeries
#  class            | EDDTableFromNcFiles
#  title            | EPA Beaches Model...
#  minLongitude     | -10.39019
#  maxLongitude     | -6.007815
#  longitudeSpacing | NaN
#  minLatitude      | 51.44835
#  maxLatitude      | 55.30617
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | 2023-01-01T00:00:00Z
#  maxTime          | 2026-01-01T00:00:00Z
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | https://erddap.ma...
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | http://www.marine...
#  infoUrl          | http://milas.mari...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | MI Modelled Tide ...
# -RECORD 15-------------------------------
#  datasetID        | IMI-WaveBuoyForecast
#  accessible       | public
#  institution      | Marine Institute
#  dataStructure    | table
#  cdm_data_type    | TimeSeries
#  class            | EDDTableFromNcFiles
#  title            | MI Wave Forecast ...
#  minLongitude     | -15.93
#  maxLongitude     | -5.425
#  longitudeSpacing | NaN
#  minLatitude      | 51.2166
#  maxLatitude      | 55.0
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | 2023-05-04T00:00:00Z
#  maxTime          | 2023-05-13T00:00:00Z
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | https://erddap.ma...
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | http://www.marine...
#  infoUrl          | http://milas.mari...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | MI Wave Forecast ...
# -RECORD 16-------------------------------
#  datasetID        | IMI_CTD
#  accessible       | public
#  institution      | Marine Institute
#  dataStructure    | table
#  cdm_data_type    | Profile
#  class            | EDDTableFromDatabase
#  title            | Ireland's Marine ...
#  minLongitude     | -62.244
#  maxLongitude     | 18.676
#  longitudeSpacing | NaN
#  minLatitude      | 10.1375
#  maxLatitude      | 78.9148333
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | 1999-07-09T10:49:24Z
#  maxTime          | 2023-04-07T15:37:13Z
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | (source database)
#  infoUrl          | http://data.marin...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | CTD (Conductivity...
# -RECORD 17-------------------------------
#  datasetID        | IWBNetwork
#  accessible       | public
#  institution      | Marine Institute
#  dataStructure    | table
#  cdm_data_type    | TimeSeries
#  class            | EDDTableFromDatabase
#  title            | Irish Weather Buo...
#  minLongitude     | -15.88135
#  maxLongitude     | -5.4302
#  longitudeSpacing | NaN
#  minLatitude      | 51.215956
#  maxLatitude      | 54.999967
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | null
#  maxTime          | null
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | (source database)
#  infoUrl          | http://data.marin...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | Real time meteoro...
# -RECORD 18-------------------------------
#  datasetID        | IWaveBNetwork
#  accessible       | public
#  institution      | Marine Institute
#  dataStructure    | table
#  cdm_data_type    | TimeSeries
#  class            | EDDTableFromDatabase
#  title            | Irish Wave Buoys
#  minLongitude     | -10.2961
#  maxLongitude     | -9.267
#  longitudeSpacing | NaN
#  minLatitude      | 51.647
#  maxLatitude      | 54.27958
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | null
#  maxTime          | null
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | (source database)
#  infoUrl          | http://www.isde.i...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | Irish Wave Buoys
# -RECORD 19-------------------------------
#  datasetID        | IWaveBNetwork30Min
#  accessible       | public
#  institution      | Marine Institute
#  dataStructure    | table
#  cdm_data_type    | TimeSeries
#  class            | EDDTableFromDatabase
#  title            | Irish Wave Buoys ...
#  minLongitude     | -10.2961
#  maxLongitude     | -9.267
#  longitudeSpacing | NaN
#  minLatitude      | 51.647
#  maxLatitude      | 54.27958
#  latitudeSpacing  | NaN
#  minAltitude      | NaN
#  maxAltitude      | NaN
#  minTime          | null
#  maxTime          | null
#  timeSpacing      | NaN
#  griddap          | null
#  subset           | https://erddap.ma...
#  tabledap         | https://erddap.ma...
#  MakeAGraph       | https://erddap.ma...
#  sos              | null
#  wcs              | null
#  wms              | null
#  files            | null
#  fgdc             | https://erddap.ma...
#  iso19115         | https://erddap.ma...
#  metadata         | https://erddap.ma...
#  sourceUrl        | (source database)
#  infoUrl          | http://www.isde.i...
#  rss              | https://erddap.ma...
#  email            | null
#  testOutOfDate    | null
#  outOfDate        | NaN
#  summary          | Irish Wave Buoys ...
# only showing top 20 rows
