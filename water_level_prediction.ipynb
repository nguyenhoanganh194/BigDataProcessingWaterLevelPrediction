# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import sys
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.master("local").appName("Irish Marine Institute - Data Prep").getOrCreate()

# %%
df = spark.read.csv("dataset/IrishNationalTideGaugeNetwork.csv", header=True, inferSchema=True)
df.show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  time                 | UTC
#  altitude             | m
#  latitude             | degrees_north
#  longitude            | degrees_east
#  station_id           | null
#  datasourceid         | null
#  Water_Level_LAT      | metres
#  Water_Level_OD_Malin | metres
#  QC_Flag              | null
# -RECORD 1------------------------------------
#  time                 | 2006-10-26T13:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.679
#  Water_Level_OD_Malin | 1.82
#  QC_Flag              | 1
# -RECORD 2------------------------------------
#  time                 | 2006-10-26T14:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.939
#  Water_Level_OD_Malin | 2.08
#  QC_Flag              | 1
# -RECORD 3------------------------------------
#  time                 | 2006-10-26T14:06:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.969
#  Water_Level_OD_Malin | 2.11
#  QC_Flag              | 1
# -RECORD 4------------------------------------
#  time                 | 2006-10-26T14:12:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.859
#  Water_Level_OD_Malin | 2.0
#  QC_Flag              | 1
# -RECORD 5------------------------------------
#  time                 | 2006-10-26T14:18:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.809
#  Water_Level_OD_Malin | 1.95
#  QC_Flag              | 1
# -RECORD 6------------------------------------
#  time                 | 2006-10-26T14:24:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.789
#  Water_Level_OD_Malin | 1.93
#  QC_Flag              | 1
# -RECORD 7------------------------------------
#  time                 | 2006-10-26T14:30:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.739
#  Water_Level_OD_Malin | 1.88
#  QC_Flag              | 1
# -RECORD 8------------------------------------
#  time                 | 2006-10-26T14:36:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.669
#  Water_Level_OD_Malin | 1.81
#  QC_Flag              | 1
# -RECORD 9------------------------------------
#  time                 | 2006-10-26T14:42:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.609
#  Water_Level_OD_Malin | 1.75
#  QC_Flag              | 1
# -RECORD 10-----------------------------------
#  time                 | 2006-10-26T14:48:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.579
#  Water_Level_OD_Malin | 1.72
#  QC_Flag              | 1
# -RECORD 11-----------------------------------
#  time                 | 2006-10-26T14:54:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.499
#  Water_Level_OD_Malin | 1.64
#  QC_Flag              | 1
# -RECORD 12-----------------------------------
#  time                 | 2006-10-26T15:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.479
#  Water_Level_OD_Malin | 1.62
#  QC_Flag              | 1
# -RECORD 13-----------------------------------
#  time                 | 2006-10-26T15:06:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.359
#  Water_Level_OD_Malin | 1.5
#  QC_Flag              | 1
# -RECORD 14-----------------------------------
#  time                 | 2006-10-26T15:12:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.289
#  Water_Level_OD_Malin | 1.43
#  QC_Flag              | 1
# -RECORD 15-----------------------------------
#  time                 | 2006-10-26T15:18:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.259
#  Water_Level_OD_Malin | 1.4
#  QC_Flag              | 1
# -RECORD 16-----------------------------------
#  time                 | 2006-10-26T15:24:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.139
#  Water_Level_OD_Malin | 1.28
#  QC_Flag              | 1
# -RECORD 17-----------------------------------
#  time                 | 2006-10-26T15:30:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.049
#  Water_Level_OD_Malin | 1.19
#  QC_Flag              | 1
# -RECORD 18-----------------------------------
#  time                 | 2006-10-26T15:36:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 3.969
#  Water_Level_OD_Malin | 1.11
#  QC_Flag              | 1
# -RECORD 19-----------------------------------
#  time                 | 2006-10-26T15:42:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 3.859
#  Water_Level_OD_Malin | 1.0
#  QC_Flag              | 1
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- time: string (nullable = true)
#  |-- altitude: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- station_id: string (nullable = true)
#  |-- datasourceid: integer (nullable = true)
#  |-- Water_Level_LAT: string (nullable = true)
#  |-- Water_Level_OD_Malin: string (nullable = true)
#  |-- QC_Flag: integer (nullable = true)

# %%
from pyspark.sql.functions import from_utc_timestamp
from pyspark.sql.functions import col
from pyspark.sql.functions import year, to_date
from pyspark.sql.functions import dayofmonth, month, year,hour, minute

# Convert the string column to a datetime column
df = df.withColumn("Water_Level_LAT", col("Water_Level_LAT").cast("float"))
df = df.withColumn("Water_Level_OD_Malin", col("Water_Level_OD_Malin").cast("float"))
df = df.withColumn("latitude", col("latitude").cast("float"))
df = df.withColumn("longitude", col("longitude").cast("float"))

df = df.withColumn("minute", minute(to_date(df.time)))
df = df.withColumn("hour", hour(to_date(df.time)))
df = df.withColumn("day", dayofmonth(to_date(df.time)))
df = df.withColumn("month", month(to_date(df.time)))
df = df.withColumn("year", year(to_date(df.time)))


df = df.withColumn("day", dayofmonth(to_date(df.time)))
df = df.withColumn("month", month(to_date(df.time)))
df = df.withColumn("year", year(to_date(df.time)))

df = df.filter((df.latitude == '53.585') & (df.longitude == '-6.1081'))
df = df.na.drop()
df.show()
df.printSchema()
# Out:
# +--------------------+--------+--------+---------+----------------+------------+---------------+--------------------+-------+------+----+---+-----+----+
# |                time|altitude|latitude|longitude|      station_id|datasourceid|Water_Level_LAT|Water_Level_OD_Malin|QC_Flag|minute|hour|day|month|year|
# +--------------------+--------+--------+---------+----------------+------------+---------------+--------------------+-------+------+----+---+-----+----+
# |2006-10-26T13:00:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.679|                1.82|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:00:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.939|                2.08|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:06:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.969|                2.11|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:12:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.859|                 2.0|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:18:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.809|                1.95|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:24:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.789|                1.93|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:30:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.739|                1.88|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:36:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.669|                1.81|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:42:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.609|                1.75|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:48:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.579|                1.72|      1|     0|   0| 26|   10|2006|
# |2006-10-26T14:54:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.499|                1.64|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:00:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.479|                1.62|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:06:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.359|                 1.5|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:12:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.289|                1.43|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:18:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.259|                 1.4|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:24:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.139|                1.28|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:30:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          4.049|                1.19|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:36:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          3.969|                1.11|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:42:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          3.859|                 1.0|      1|     0|   0| 26|   10|2006|
# |2006-10-26T15:48:00Z|     0.0|  53.585|  -6.1081|Skerries Harbour|          11|          3.809|                0.95|      1|     0|   0| 26|   10|2006|
# +--------------------+--------+--------+---------+----------------+------------+---------------+--------------------+-------+------+----+---+-----+----+
# only showing top 20 rows
#
# root
#  |-- time: string (nullable = true)
#  |-- altitude: string (nullable = true)
#  |-- latitude: float (nullable = true)
#  |-- longitude: float (nullable = true)
#  |-- station_id: string (nullable = true)
#  |-- datasourceid: integer (nullable = true)
#  |-- Water_Level_LAT: float (nullable = true)
#  |-- Water_Level_OD_Malin: float (nullable = true)
#  |-- QC_Flag: integer (nullable = true)
#  |-- minute: integer (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- year: integer (nullable = true)

# %%
df.dtypes
# Out:
# [('time', 'string'),
#  ('altitude', 'string'),
#  ('latitude', 'float'),
#  ('longitude', 'float'),
#  ('station_id', 'string'),
#  ('datasourceid', 'int'),
#  ('Water_Level_LAT', 'float'),
#  ('Water_Level_OD_Malin', 'float'),
#  ('QC_Flag', 'int'),
#  ('minute', 'int'),
#  ('hour', 'int'),
#  ('day', 'int'),
#  ('month', 'int'),
#  ('year', 'int')]

# %%
from pyspark.ml.feature import StringIndexer
indexer = StringIndexer(inputCol="time" ,outputCol="indexedTime")
indexed = indexer.fit(df).transform(df)
indexed.show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  time                 | 2006-10-26T13:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.679
#  Water_Level_OD_Malin | 1.82
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 0.0
# -RECORD 1------------------------------------
#  time                 | 2006-10-26T14:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.939
#  Water_Level_OD_Malin | 2.08
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 1.0
# -RECORD 2------------------------------------
#  time                 | 2006-10-26T14:06:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.969
#  Water_Level_OD_Malin | 2.11
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 2.0
# -RECORD 3------------------------------------
#  time                 | 2006-10-26T14:12:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.859
#  Water_Level_OD_Malin | 2.0
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 3.0
# -RECORD 4------------------------------------
#  time                 | 2006-10-26T14:18:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.809
#  Water_Level_OD_Malin | 1.95
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 4.0
# -RECORD 5------------------------------------
#  time                 | 2006-10-26T14:24:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.789
#  Water_Level_OD_Malin | 1.93
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 5.0
# -RECORD 6------------------------------------
#  time                 | 2006-10-26T14:30:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.739
#  Water_Level_OD_Malin | 1.88
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 6.0
# -RECORD 7------------------------------------
#  time                 | 2006-10-26T14:36:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.669
#  Water_Level_OD_Malin | 1.81
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 7.0
# -RECORD 8------------------------------------
#  time                 | 2006-10-26T14:42:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.609
#  Water_Level_OD_Malin | 1.75
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 8.0
# -RECORD 9------------------------------------
#  time                 | 2006-10-26T14:48:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.579
#  Water_Level_OD_Malin | 1.72
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 9.0
# -RECORD 10-----------------------------------
#  time                 | 2006-10-26T14:54:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.499
#  Water_Level_OD_Malin | 1.64
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 10.0
# -RECORD 11-----------------------------------
#  time                 | 2006-10-26T15:00:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.479
#  Water_Level_OD_Malin | 1.62
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 11.0
# -RECORD 12-----------------------------------
#  time                 | 2006-10-26T15:06:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.359
#  Water_Level_OD_Malin | 1.5
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 12.0
# -RECORD 13-----------------------------------
#  time                 | 2006-10-26T15:12:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.289
#  Water_Level_OD_Malin | 1.43
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 13.0
# -RECORD 14-----------------------------------
#  time                 | 2006-10-26T15:18:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.259
#  Water_Level_OD_Malin | 1.4
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 14.0
# -RECORD 15-----------------------------------
#  time                 | 2006-10-26T15:24:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.139
#  Water_Level_OD_Malin | 1.28
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 15.0
# -RECORD 16-----------------------------------
#  time                 | 2006-10-26T15:30:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 4.049
#  Water_Level_OD_Malin | 1.19
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 16.0
# -RECORD 17-----------------------------------
#  time                 | 2006-10-26T15:36:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 3.969
#  Water_Level_OD_Malin | 1.11
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 17.0
# -RECORD 18-----------------------------------
#  time                 | 2006-10-26T15:42:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 3.859
#  Water_Level_OD_Malin | 1.0
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 18.0
# -RECORD 19-----------------------------------
#  time                 | 2006-10-26T15:48:00Z
#  altitude             | 0.0
#  latitude             | 53.585
#  longitude            | -6.1081
#  station_id           | Skerries Harbour
#  datasourceid         | 11
#  Water_Level_LAT      | 3.809
#  Water_Level_OD_Malin | 0.95
#  QC_Flag              | 1
#  minute               | 0
#  hour                 | 0
#  day                  | 26
#  month                | 10
#  year                 | 2006
#  indexedTime          | 19.0
# only showing top 20 rows

# %%
fd_1 = indexed.selectExpr("cast(time as string)dateTime",
                          "cast(minute as int)minute",
                          "cast(hour as int)hour",
                          "cast(day as int)day",
                          "cast(month as int)month",
                          "cast(year as int)year",
                          "cast(Water_Level_LAT as float)label",
                          "cast(Water_Level_OD_Malin as float) Water_Level_OD_Malin")

tran_fd_1 = fd_1.filter((fd_1.year < 2020))
test_fd_1 = fd_1.filter((fd_1.year > 2019))

# %%
from pyspark.ml.feature import VectorAssembler
vectorAssembler = VectorAssembler(inputCols = ['minute','hour','day','month','year'],
                                  handleInvalid="skip",
                                  outputCol ='features')

# %%
vhouse_df_tran = vectorAssembler.transform(tran_fd_1)
trainingData = vhouse_df_tran.select("features", "label")
trainingData.show()

vhouse_df_test = vectorAssembler.transform(test_fd_1)
testData = vhouse_df_test.select("features", "label")
testData.show()
# Out:
# +--------------------+-----+
# |            features|label|
# +--------------------+-----+
# |[0.0,0.0,26.0,10....|4.679|
# |[0.0,0.0,26.0,10....|4.939|
# |[0.0,0.0,26.0,10....|4.969|
# |[0.0,0.0,26.0,10....|4.859|
# |[0.0,0.0,26.0,10....|4.809|
# |[0.0,0.0,26.0,10....|4.789|
# |[0.0,0.0,26.0,10....|4.739|
# |[0.0,0.0,26.0,10....|4.669|
# |[0.0,0.0,26.0,10....|4.609|
# |[0.0,0.0,26.0,10....|4.579|
# |[0.0,0.0,26.0,10....|4.499|
# |[0.0,0.0,26.0,10....|4.479|
# |[0.0,0.0,26.0,10....|4.359|
# |[0.0,0.0,26.0,10....|4.289|
# |[0.0,0.0,26.0,10....|4.259|
# |[0.0,0.0,26.0,10....|4.139|
# |[0.0,0.0,26.0,10....|4.049|
# |[0.0,0.0,26.0,10....|3.969|
# |[0.0,0.0,26.0,10....|3.859|
# |[0.0,0.0,26.0,10....|3.809|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-------+
# |            features|  label|
# +--------------------+-------+
# |[0.0,0.0,3.0,11.0...|-29.904|
# |[0.0,0.0,3.0,11.0...|-29.904|
# |[0.0,0.0,3.0,11.0...|-29.904|
# |[0.0,0.0,3.0,11.0...|-29.899|
# |[0.0,0.0,3.0,11.0...|-29.904|
# |[0.0,0.0,3.0,11.0...|  3.097|
# |[0.0,0.0,3.0,11.0...|  3.022|
# |[0.0,0.0,3.0,11.0...|  2.965|
# |[0.0,0.0,3.0,11.0...|  2.897|
# |[0.0,0.0,3.0,11.0...|  2.801|
# |[0.0,0.0,3.0,11.0...|   2.72|
# |[0.0,0.0,3.0,11.0...|  2.637|
# |[0.0,0.0,3.0,11.0...|  2.561|
# |[0.0,0.0,3.0,11.0...|  2.477|
# |[0.0,0.0,3.0,11.0...|  2.399|
# |[0.0,0.0,3.0,11.0...|  2.326|
# |[0.0,0.0,3.0,11.0...|  2.241|
# |[0.0,0.0,3.0,11.0...|  2.158|
# |[0.0,0.0,3.0,11.0...|  2.076|
# |[0.0,0.0,3.0,11.0...|  2.005|
# +--------------------+-------+
# only showing top 20 rows

# %%
from pyspark.ml.regression import LinearRegression
gbt = GBTRegressor(featuresCol="features", maxIter=30, maxDepth = 11)
# Chain indexer and GBT in a Pipeline
#pipeline = Pipeline(stages=[featureIndexer, gbt])
# Train model. This also runs the indexer.
model1 = gbt.fit(trainingData)
# Make predictions.
tdata2 = model1.transform(testData)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 from pyspark.ml.regression import LinearRegression
# ----> 2 gbt = GBTRegressor(featuresCol="features", maxIter=30, maxDepth = 11)
#       3 # Chain indexer and GBT in a Pipeline
#       4 #pipeline = Pipeline(stages=[featureIndexer, gbt])
#       5 # Train model. This also runs the indexer.
#       6 model1 = gbt.fit(trainingData)
#
# NameError: name 'GBTRegressor' is not defined

# %%
from pyspark.ml.regression import GBTRegressor
from pyspark.ml.feature import VectorIndexer
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline

# %%
# Automatically identify categorical features, and index them.
# Set maxCategories so features with > 4 distinct values are treated as continuous.
featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures",
                               handleInvalid="skip").fit(trSet)
# Split the data into training and test sets (30% held out for testing)
(trainingData, testData) = trSet.randomSplit([0.7, 0.3])
# Train a GBT model.
gbt = GBTRegressor(featuresCol="indexedFeatures", maxIter=30, maxDepth = 11)
# Chain indexer and GBT in a Pipeline
pipeline = Pipeline(stages=[featureIndexer, gbt])
# Train model. This also runs the indexer.
model0 = pipeline.fit(trainingData)
# Make predictions.
tdata2 = model0.transform(testData)
# Select (prediction, true label) and compute test error
evaluator = RegressionEvaluator(labelCol="label", predictionCol="prediction", metricName="r2")
rmse = evaluator.evaluate(tdata2)
print("R Squared on test data = %g" % rmse)
gbtModel = model0.stages[1]
print(gbtModel) 
# summary only 8)Getting Important Features
model0.stages[1].featureImportances
model0.stages[-1].trees

# %%
evaluator = RegressionEvaluator(labelCol="label", predictionCol="prediction", metricName="mae")
mae= evaluator.evaluate(tdata2)
print("MAE on test data = %g" % mae)

# %%
sf03 = tdata2.toPandas()
import seaborn
import matplotlib.pyplot as plt
from scipy.stats import *
seaborn.set(style="whitegrid", font_scale = 1.8)
fig, ax = plt.subplots()
seaborn.set(color_codes=True)
seaborn.set(rc={'figure.figsize':(20, 10)})
seaborn.regplot(x="label", y="prediction", fit_reg=False, ax=ax,data = sf03,scatter_kws={"color": "b"});
seaborn.regplot(x="label", y="prediction",scatter=False, ax=ax, data = sf03 , line_kws={"color": "red"});

# %%
tdata2.show()
